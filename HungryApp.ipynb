# %% [markdown]
# # Food Delivery App

# %% [markdown]
# You have to design a Food Ordering app for a restaurant.
#
#
#
# The application will have a log-in for admin and users.
#
#
#
# Admin will have the following functionalities:
#
# Add new food items. Food Item will have the following details:
# FoodID //It should be generated automatically by the application.
# Name
# Quantity. For eg, 100ml, 250gm, 4pieces etc
# Price
# Discount
# Stock. Amount left in stock in the restaurant.
# Edit food items using FoodID.
# View the list of all food items.
# Remove a food item from the menu using FoodID.
#
#
#
#
# The user will have the following functionalities:
#
# Register on the application. Following to be entered for registration:
# Full Name
# Phone Number
# Email
# Address
# Password
# Log in to the application
# The user will see 3 options:
# Place New Order
# Order History
# Update Profile
# Place New Order: The user can place a new order at the restaurant.
# Show list of food. The list item should as follows:
# 1. Tandoori Chicken (4 pieces) [INR 240]
# 2. Vegan Burger (1 Piece) [INR 320]
# 3. Truffle Cake (500gm) [INR 900]
# Users should be able to select food by entering an array of numbers. For example, if the user wants to order Vegan Burger and Truffle Cake they should enter [2, 3]
# Once the items are selected user should see the list of all the items selected. The user will also get an option to place an order.
# Order History should show a list of all the previous orders
# Update Profile: the user should be able to update their profile.
#
#
# Upload the python files on Github and submit the Github repo URL.

# %%
class HungryApp:
    def __init__(self):
        self.food=[]
        self.fooditems={}
    def add_food(self):
        self.food_id=input(' create food ID')
        n = input('enter the food name')
        self.food.append(n)
        q= int(input('enter the quantitiy of food'))
        self.food.append(q)
        p= int(input('enter the price of the food'))
        self.food.append(p)
        d= int(input('enter the discount for the food'))
        self.food.append(d)
        s= int(input('enter the stock in gms/liters/piece:'))
        self.food.append(s)
        self.fooditems[self.food_id]=self.food
        print('food in the dict', self.fooditems)
    def edit_items(self):
        fid=input('enter food ID')
        if fid in self.fooditems:
            a=int(input('enter \n 1 - to change food ID \n 2 - to Change the item name \n 3 - To change the quantity \n 4 - to change the price \n 5- to change the discount \n 6- to change the stock'))
            if a==1:
                b=self.fooditems[fid]
                self.fooditems.pop(fid)
                c=input('enter new ID for that food item:')
                self.fooditem[c]=b
                print(' your food item has been updated successfully')
            if a==2:
                self.fooditems[fid][0]=input('please enter new name to the food item')
                print(' food item name changed successfully')
            if a==3:
                print(' food items current quantity is:', self.fooditems[fid][1]) 
                   
            if a==4:
                    self.fooditems[fid][2]=int(input('please enter the price'))
                    print(' food item price updated')
            if a==5:
                    self.fooditems[fid][3]=int(input('please enter the new discount'))
                    print('discount updated successfully')
            if a==6:
                    s=int(input(" \n Enter \n 1 - To add quantity manually \n 2 - To reduce quantity manually \n  3 - To Change the quantity completely" ))
                    if s==1:
                        ad=int(input(" \n Enter the quantity that need to be added "))

                        self.fooditems[fid][1]=self.fooditems[fid][1]+ad
                        print(" \n  Your food's quantity added sucessfully  & your current quantity is ",self.fooditems[fid][1])
                    if s==2:
                        su=int(input(" \n Enter the quantity that need to be added "))

                        self.fooditems[fid][1]=self.fooditems[fid][1]-su
                        print(" \n  Your foods's quantity reduced sucessfully  & your current quantity is ",self.fooditems[fid][1])
                    if s==3:
                        nv=int(input(" \n  Enter the foods's quantity that need to be displayed : "))
                        self.items[fid][1]=nv
                        
                    else:
                        print(" \n  You had entered invalid input please try again ")
            else:
                    print(" \n Your food id is not found ")
    
          
    def discount(self):
        t=input("\n 10% discount available on every order plz hurry \n enter y or Y to avail this offer")
        if t== "y" or "Y":
            self.fooditems[2]= self.fooditems[2] - self.fooditems[2]//10
            print("\n Discount applied successfully ")
        else:
            print("\n Discount not selected ")
    
    def view_food_details(self):
        fid=input('enter your food ID')
        if fid in self.fooditems:
            a=int(input("enter \n 1 - View food ID \n 2 - to view food name \n 3 - to view the price \n 4 - to view the quantity \n 5 - to view the no. of items you have \n 6 - to view all details"))
            if a==1:
                print(' food ID is:', self.fooditems[fid])
            if a==2:
                print(' name of the food:', self.fooditems[fid][0])
            if a==3:
                print('price of the food:', self.fooditems[fid][2])
            if a==4:
                print('quantity available:', self.fooditems[fid][1])
            if a==5:
                print(' total items:', len(list(self.fooditems.keys())))
                m=0
                for i in self.fooditems:
                    m+=i[3]
                print('total stock of all the food items:', m)
            if a==6:
                print('food ID is:', self.fooditems[fid])
                print('name of the food:', self.fooditems[fid][0])
                print('price of the food item:', self.fooditems[fid][2])
                print('quantity of the food:', self.fooditems[fid][1])
        else:
            print('food item not found')
            
   
    
class customer(HungryApp):
    def __init__(self):
      # self.Account=Account
   #    self.Register= Register
    #   self.login == False
     #  self.payment = payment 
      # self.menu = menu
       #self.cart = cart
        super().__init__()
        self.customer_details={}
        #self.customer_detail={}
        self.order_details={}
        self.sno=1     
        
        
        
        
        
    def Register(self):   
        
        self.cust_name=input("\n Enter your full name ")
        a=int(input("\n Enter your number , it must be 10 digits "))
        if len(str(a))==10:
            self.cust_contact_number=a
        else:
            print("\n Your mobail number does not contains 10 digits ")
        self.mail_id=input("\n Enter your mail-id ")
        self.address=input("\n Enter your address in a single line(ie without using enter key) ")
        self.password=input("Enter your password : ")
        s={}
        s["customer_name"]=self.cust_name
        s["customer_contact_number"]=self.cust_contact_number
        s["customer_mail_id"]=self.mail_id
        s["customer_address"]=self.address
        s["customer_password"]=self.password
        
        self.customer_details[self.cust_contact_number]=s
        self.customer_details[self.password]=s
        print("\n Your registration process completed sucessfully ")
        
        print("\n customers_details \n\n ",self.customer_details)

        
    def Account(self):
        num= int(input("Enter your registerd Mobile Num:"))
        if num in self.customer_details:
            pas= input('Enter your password')
            if pas ==self.password:
                print('Logged in Successfully')
                f=int(input("Enter 1 - New order \n 2 - Order history \n 3 - update profile"))
                if f==1:
                    k=1
                    for i in self.fooditems:
                        print(' the food menu with availabilty and price')
                        print('sl.no', k, '\n')
                        print('food ID    :', i)
                        print('Food Name:', self.fooditems[i][0])
                        print('Price:', self.fooditems[i][2])
                        print('Available Quantity:', self.fooditems[i][1])
                        k+=1
                    sel=input('enter the food ID you want to order')
                    if sel in self.fooditems:
                        qt=int(input('enter the quantity of food item'))
                        if self.fooditems[sel][3]>=qt:
                            print("\n The price for ",qt," quantity will be ",qt*self.fooditems[sel][2]," if ok to continue order type 'y' ")
                            ops=input()
                            if ops=="y" or "Y":
                                di={}
                                d={}
                                self.fooditems[sel][3]-=qt
                                d["number"]=num
                                d["food ID ID"]=sel
                                d["Food name"]=self.fooditems[sel][0]
                                d["quantity"]=qt
                                #di[self.sno]=d                  # id,name,qty
                                self.order_details[self.sno]=d   # numb: d(name,qty)
                                self.sno+=1
                                print("\n Your order has been created sucessfully ")
                            else:
                                 print("\n Sorry there is only  ", self.products[sel][3]," quantity available in stock ")
                    else:
                        print("\n You had entered invalid product id ")
                            
       
                if f==2:
                    for i in self.order_details:
                        if num in self.order_details[i]["number"]:
                            print("\n History of food id - ",self.order_details[i]["food ID"],"  name - ",self.order_details[i]["food name"]," Quantity - ",self.order_details[i]["quantity"])
                    
                       
                        
                    print("-----------")
                      
                if f==3:
                    x= int(input("\n Enter your number "))
                    if x in self.customer_details:
                        e= list(self.customer_details.values())[0]
                        n= int(input(" \n 1 to change name \n 2 to change mail \n 3 to change number \n 4 to change password \n 5 to change address "))
                        if n==1:
                            e["user_name"]= input("\n Enter new user name ")
                            print("\n Profile updated sucessfully ", self.customer_details)
                    
                        elif n==2:
                            e["user_name"]= input("\n Enter new mail ")
                            print("\n Profile updated sucessfully ", self.customer_details)
                    
                        elif n==3:
                            e["user_number"]=int(input("\n Enter new number "))
                            print("\n Profile updated sucessfully ", self.customer_details)
                     
                        elif n==4:
                            e["user_pass"]= input("\n Enter new password ")
                            print("\n Profile updated sucessfully ", self.customer_details)
                     
                        elif n==5:
                            e["user_address"]= input("\n Enter new address ")
                            print("\n Profile updated sucessfully ", self.customer_details)
                            
                    else:
                        print("Entered wrong number")
                        
                        
            else:
                print('wrong Password Please Re-Enter the Password')
        else:
            print('Account doesnt exist pls Register')

           
    def menu(self):
        v=True
   
        while v:
                r=int(input("""Enter \n 1 - To Add food \n 2 - To View food details \n 3 - To update/change fooditem details \n 4 - For Customer register \n 5 - For Customer login \n 6 - To Exit"""))
                if r==1:
                    self.add_food()
                elif r==2:
                    self.view_food_details()
                elif r==3:
                    self.edit_items()
                elif r==4:
                    self.Register()
                elif r==5:
                    self.Account()
                elif r==6:
                      v=False
        

        else:
            print("You had entered wrong input")
            
            

c1=customer()
c1.menu()
